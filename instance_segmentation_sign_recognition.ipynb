# %%
# !pip install ultralytics
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image
model = YOLO('yolov8n-seg.pt')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ^C
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().system('pip install ultralytics')
# ----> 2 from ultralytics import YOLO
#       3 from matplotlib import pyplot as plt
#       4 from PIL import Image
#
# ModuleNotFoundError: No module named 'ultralytics'
# Collecting ultralytics
#   Using cached ultralytics-8.2.102-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (1.26.4)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (1.14.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.4.1-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.19.1-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from ultralytics) (2.2.3)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.8-py3-none-any.whl.metadata (9.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: fsspec in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\frans\desktop\realtimegesturedetection\.venv\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Using cached ultralytics-8.2.102-py3-none-any.whl (874 kB)
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached torch-2.4.1-cp312-cp312-win_amd64.whl (199.4 MB)
# Using cached torchvision-0.19.1-cp312-cp312-win_amd64.whl (1.3 MB)
# Using cached ultralytics_thop-2.0.8-py3-none-any.whl (26 kB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Installing collected packages: opencv-python, jinja2, contourpy, torch, matplotlib, ultralytics-thop, torchvision, seaborn, ultralytics
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\frans\\Desktop\\RealTimeGestureDetection\\.venv\\Lib\\site-packages\\tests\\test_integrations.py'
# Check the permissions.

# %%
# !unzip /content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/try_again/sign_recognition_yolov8.zip

# %%
path = "/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/try_again/"

# %%
results = model.train(data='data.yaml',
                      project=path+"result_dir",
                      name="trained_100_epochs",
                      batch = 80,
                      epochs=100)

# %%
mymodel = YOLO("/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/try_again/result_dir/trained_100_epochs/weights/best.pt")
res0 = mymodel.predict('/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/MergedImages(1).jpg', conf = 0.6)[0]

new_result_array = res0.plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)

# %%
res1 = mymodel.predict('/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/MergedImages.jpg', conf = 0.6)[0]

new_result_array = res1.plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)
