# %%
# !pip install ultralytics
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image
model = YOLO('yolov8n-seg.pt')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 4.1 MB/s eta 0:00:00
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 88.8MB/s]
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/try_again/sign_recognition_yolov8.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: test/labels/9-17-_jpg.rf.71b9f4a3ee64a6cd3a761db365259f29.txt
#  extracting: test/labels/9-23-_jpg.rf.4c8657c377e45cb0f445769c21999454.txt
#  extracting: test/labels/9-3-_jpg.rf.dbc6f3e7ff233544744a618092e56168.txt
#  extracting: test/labels/9-30-_jpg.rf.8283e9aed4fc42ac604185af1d73b1d8.txt
#  extracting: test/labels/A-18-_jpg.rf.b17e2bb471dda134018234b656ea1eca.txt
#  extracting: test/labels/B-11-_jpg.rf.005b55868a3b079a351182096ada6a1c.txt
#  extracting: test/labels/B-14-_jpg.rf.3d950420343122ef15a6098d0a49d6b7.txt
#  extracting: test/labels/B-26-_jpg.rf.31b3f75d12bb45623556c9fa2a3a31cb.txt
#  extracting: test/labels/C-23-_jpg.rf.53a5266c87302508e42e5451bad9ea5f.txt
#  extracting: test/labels/C-9-_jpg.rf.975ac4b54ac0bcbdd134a325d0e2a9f8.txt
#  extracting: test/labels/D-26-_jpg.rf.d975d45a646a09ce5d86cbe7abac1c5d.txt
#  extracting: test/labels/D-27-_jpg.rf.82824356ceca5c51a7e9459f30dd85cd.txt
# ...

# %%
path = "/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/try_again/"

# %%
results = model.train(data='data.yaml',
                      project=path+"result_dir",
                      name="trained_100_epochs",
                      batch = 80,
                      epochs=100)
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
mymodel = YOLO("/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/try_again/result_dir/trained_100_epochs/weights/best.pt")
res0 = mymodel.predict('/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/MergedImages(1).jpg', conf = 0.6)[0]

new_result_array = res0.plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)
# Out:
# image 1/1 /content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/MergedImages(1).jpg: 640x640 1 C, 1 G, 1 K, 1 R, 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
res1 = mymodel.predict('/content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/MergedImages.jpg', conf = 0.6)[0]

new_result_array = res1.plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)
# Out:
# image 1/1 /content/drive/MyDrive/sign_lang_instance_segmentation_yolov8/MergedImages.jpg: 640x640 3 0s, 1 1, 22.7ms
# Speed: 1.8ms preprocess, 22.7ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
